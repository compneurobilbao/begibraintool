# %%
import generate_colored_silhouettes

generate_colored_silhouettes.process_csv(csv_path='../BL6.csv')
# Out:
# ['intento', 'contrast_path_0', 'contrast_path_1', 'contrast_path_2', 'posicion_angular', 'tipo', 'excentricidad', 'respuesta', 'tamanyo', 'color_h', 'color_s', 'color_v']
# Guardada imagen: ../images/autogenerated_datasets/color_semantic_silhouetes\animals\B_N209044_silhouette.png
# ['intento', 'contrast_path_0', 'contrast_path_1', 'contrast_path_2', 'posicion_angular', 'tipo', 'excentricidad', 'respuesta', 'tamanyo', 'color_h', 'color_s', 'color_v']
# Guardada imagen: ../images/autogenerated_datasets/color_semantic_silhouetes\animals\B_N253041_silhouette.png
# ['intento', 'contrast_path_0', 'contrast_path_1', 'contrast_path_2', 'posicion_angular', 'tipo', 'excentricidad', 'respuesta', 'tamanyo', 'color_h', 'color_s', 'color_v']
# Guardada imagen: ../images/autogenerated_datasets/color_semantic_silhouetes\animals\B_N253081_silhouette.png
# ...
